# %% [markdown]
# <a href="https://colab.research.google.com/github/Rudh1830/Connecting-Snowflake-to-Python-for-Data-Extraction-and-Analysis/blob/main/E_Commerce_Data_Analysis_Using_Snowflake_%26_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install snowflake-connector-python

# %%
import pandas as pd
import snowflake.connector
conn = snowflake.connector.connect(
account = "xxxxxxxxxx",
user = "xxxxxxxxx",
password = "xxxxxxx",
role = "xxxxxxx",
warehouse = "xxxxxxxxxxx",
database = "xxxxxxxxxx",
schema = "PUBLIC")

# %%
query = 'SELECT * FROM "ECM"'

# %%
df = pd.read_sql(query,conn)
conn.close()
print(df.head())
# Out:
# /tmp/ipython-input-4245078195.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query,conn)
#   PRODUCT_ID     PRODUCT_NAME         CATEGORY    PRICE  DISCOUNT  TAX_RATE  \
# 0      P5760     Formal Shoes         Footwear   523.99        15        15
# 1      P8582  Washing Machine  Home Appliances   233.06         0         8
# 2      P1299          Speaker      Electronics  1889.18         5        12
# 3      P1326          Monitor      Electronics  1769.08         0        15
# 4      P3590            Jeans          Apparel   506.67        15        10
#
#    STOCK_LEVEL SUPPLIER_ID CUSTOMER_AGE_GROUP CUSTOMER_LOCATION  \
# 0          424        S993              45-54      Chicago, USA
# 1          358        S380              18-24     New York, USA
# ...
